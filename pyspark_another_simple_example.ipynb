# %% [markdown]
# <a href="https://colab.research.google.com/github/bharghavbolla/641-HW2-Bharghav/blob/main/pyspark_another_simple_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Another example of PySpark
#
# We will revisit the polynomial that you plotted for project 3 (Fall 2025).
#
# pyspark is already available in COLAB.

# %%
import pyspark

pyspark.__version__
# Out:
# '3.5.1'

# %%
# !pip install findspark
# Out:
# Collecting findspark
#   Downloading findspark-2.0.1-py2.py3-none-any.whl.metadata (352 bytes)
# Downloading findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: findspark
# Successfully installed findspark-2.0.1

# %%
import os

# Install Java 8 and set JAVA_HOME for PySpark
# !apt-get update -qq > /dev/null
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
print("JAVA_HOME set to:", os.environ["JAVA_HOME"])
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# JAVA_HOME set to: /usr/lib/jvm/java-8-openjdk-amd64

# %%
import findspark
from pyspark.sql import SparkSession

# Initialize findspark to set SPARK_HOME and add PySpark to sys.path
findspark.init()

# Create SparkSession
spark = SparkSession.builder.appName("Example").getOrCreate()

print("Spark session created successfully!")
# Out:
# Spark session created successfully!

# %%
import numpy as np
x = np.linspace(-4,4,1000)
#print(x)

# %%
x_rdd = spark.sparkContext.parallelize(x)

# %%
print(x_rdd)
# Out:
# ParallelCollectionRDD[0] at readRDDFromFile at PythonRDD.scala:289

# %% [markdown]
# The definition of the function

# %%
def f(x):
    return x**4 - 10*x**2 + 9

# %%
print (f(-4.0),f(-2.2),f(-1.0),f(0.0),f(1.0),f(2.2),f(4.0))
# Out:
# 105.0 -15.9744 0.0 9.0 0.0 -15.9744 105.0

# %%
result_rdd = x_rdd.map(f)

# %%
print(result_rdd)
# Out:
# PythonRDD[1] at RDD at PythonRDD.scala:53

# %%
max_value = result_rdd.reduce(max)
min_value = result_rdd.reduce(min)
print("The min value is: ",min_value)
print("The max value is: ",max_value)
# Out:
# The min value is:  -15.999905707916039
# The max value is:  105.0

# %%
import math
def g(x):
 return math.sin(x)

# %%
result_rdd = x_rdd.map(g)

# %%
max_value = result_rdd.reduce(max)
min_value = result_rdd.reduce(min)
print("The min value is: ",min_value)
print("The max value is: ",max_value)
# Out:
# The min value is:  -0.999996143452644
# The max value is:  0.999996143452644
